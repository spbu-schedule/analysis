# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
# %config InlineBackend.figure_format = 'svg' 
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

# %% [markdown]
# # Преобразование части реальных данных к нужному виду

# %%
df = pd.read_csv('data.csv', sep='~', encoding = 'utf-8')
df.head()
# Out:
#                                     Oid       Id                    Start  \
# 0  32C79551-ED83-4514-8B95-004EE97BED96  1047527  2018-09-01 15:25:00.000
# 1  32C79551-ED83-4514-8B95-004EE97BED96  1047527  2018-09-08 15:25:00.000
# 2  32C79551-ED83-4514-8B95-004EE97BED96  1047527  2018-09-15 15:25:00.000
# 3  32C79551-ED83-4514-8B95-004EE97BED96  1047527  2018-09-22 15:25:00.000
# 4  32C79551-ED83-4514-8B95-004EE97BED96  1047527  2018-09-29 15:25:00.000
#
#                        End                        ContingentUnit  \
# 0  2018-09-01 17:00:00.000  75BDD1AB-F88B-4163-A153-65DB794882E5
# 1  2018-09-08 17:00:00.000  75BDD1AB-F88B-4163-A153-65DB794882E5
# 2  2018-09-15 17:00:00.000  75BDD1AB-F88B-4163-A153-65DB794882E5
# 3  2018-09-22 17:00:00.000  75BDD1AB-F88B-4163-A153-65DB794882E5
# 4  2018-09-29 17:00:00.000  75BDD1AB-F88B-4163-A153-65DB794882E5
#
#   ContingentUnitCourse ContingentUnitName                    DivisionsString  \
# 0               1 Курс          18.Б03-мм  Математико-механический факультет
# 1               1 Курс          18.Б03-мм  Математико-механический факультет
# 2               1 Курс          18.Б03-мм  Математико-механический факультет
# 3               1 Курс          18.Б03-мм  Математико-механический факультет
# 4               1 Курс          18.Б03-мм  Математико-механический факультет
#
#   DivisionName                    EducatorAssignment  \
# 0          NaN  DB47ACD1-8A86-4382-9F59-971AA37EA375
# 1          NaN  DB47ACD1-8A86-4382-9F59-971AA37EA375
# 2          NaN  DB47ACD1-8A86-4382-9F59-971AA37EA375
# 3          NaN  DB47ACD1-8A86-4382-9F59-971AA37EA375
# 4          NaN  DB47ACD1-8A86-4382-9F59-971AA37EA375
#
#          LocationsDisplayText  \
# 0  В.О., 14 линия, д. 29, 102
# 1  В.О., 14 линия, д. 29, 102
# 2  В.О., 14 линия, д. 29, 102
# 3  В.О., 14 линия, д. 29, 102
# 4  В.О., 14 линия, д. 29, 102
#
#                                              Subject
# 0  Основы наивной теории множеств, практическое з...
# 1  Основы наивной теории множеств, практическое з...
# 2  Основы наивной теории множеств, практическое з...
# 3  Основы наивной теории множеств, практическое з...
# 4  Основы наивной теории множеств, практическое з...

# %%
import time

df = pd.read_csv('data.csv', sep='~', encoding = 'utf-8', usecols=['ContingentUnitCourse', 'ContingentUnitName', 'DivisionsString', 'DivisionName','Start', 'End', 'EducatorAssignment', 'LocationsDisplayText', 'Subject'])
df.columns = ['Start', 'End', 'Курс', 'Номер группы', 'Факультет1', 'Факультет2', 'Преподаватель', 'Адрес', 'Предмет']
df['Вид занятия']=df['Предмет'].str.split(',').str.get(1)
df['Предмет']=df['Предмет'].str.split(',').str.get(0)
df['День'] = df['Start'].str.split(' ').str.get(0)
df['Время начала'] = df['Start'].str.split(' ').str.get(1)
df['Время окончания'] = df['End'].str.split(' ').str.get(1)
df['Факультет'] = df['Факультет1'].fillna(df['Факультет2'])



def convert(x):
    x = x.tm_wday
    if x == 0:
        return 'пн'
    elif x == 1:
        return 'вт'
    elif x == 2:
        return 'ср'
    elif x == 3:
        return 'чт'
    elif x == 4:
        return 'пт'
    elif x == 5:
        return 'сб'
df['День недели'] = (df['День'].apply(time.strptime, args = ('%Y-%m-%d',))).apply(convert)
df['Day'] = df['День'].apply(time.strptime, args = ('%Y-%m-%d',))

def weekNumber(x):
    return time.strftime("%W", time.strptime(x, "%Y-%m-%d"))    
df['Номер недели'] = df['День'].apply(weekNumber)
df = df[['Номер группы', 'Факультет', 'Курс', 'Преподаватель', 'Адрес', 'Предмет', 'Вид занятия', 'День', 'День недели', 'Номер недели', 'Время начала', 'Время окончания']]

df.head()
# Out:
#   Номер группы                          Факультет    Курс  \
# 0    18.Б03-мм  Математико-механический факультет  1 Курс
# 1    18.Б03-мм  Математико-механический факультет  1 Курс
# 2    18.Б03-мм  Математико-механический факультет  1 Курс
# 3    18.Б03-мм  Математико-механический факультет  1 Курс
# 4    18.Б03-мм  Математико-механический факультет  1 Курс
#
#                           Преподаватель                       Адрес  \
# 0  DB47ACD1-8A86-4382-9F59-971AA37EA375  В.О., 14 линия, д. 29, 102
# 1  DB47ACD1-8A86-4382-9F59-971AA37EA375  В.О., 14 линия, д. 29, 102
# 2  DB47ACD1-8A86-4382-9F59-971AA37EA375  В.О., 14 линия, д. 29, 102
# 3  DB47ACD1-8A86-4382-9F59-971AA37EA375  В.О., 14 линия, д. 29, 102
# 4  DB47ACD1-8A86-4382-9F59-971AA37EA375  В.О., 14 линия, д. 29, 102
#
#                           Предмет            Вид занятия        День  \
# 0  Основы наивной теории множеств   практическое занятие  2018-09-01
# 1  Основы наивной теории множеств   практическое занятие  2018-09-08
# 2  Основы наивной теории множеств   практическое занятие  2018-09-15
# 3  Основы наивной теории множеств   практическое занятие  2018-09-22
# 4  Основы наивной теории множеств   практическое занятие  2018-09-29
#
#   День недели Номер недели  Время начала Время окончания
# 0          сб           35  15:25:00.000    17:00:00.000
# 1          сб           36  15:25:00.000    17:00:00.000
# 2          сб           37  15:25:00.000    17:00:00.000
# 3          сб           38  15:25:00.000    17:00:00.000
# 4          сб           39  15:25:00.000    17:00:00.000
