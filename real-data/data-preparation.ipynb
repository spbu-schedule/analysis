# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
# %config InlineBackend.figure_format = 'svg' 
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

# %%
df = pd.read_csv('random_timetable.csv', sep=';', encoding='cp1251')
df.head()
# Out:
#    Номер группы День  Номер пары     Предмет Преподаватель Вид занятия  \
# 0           101   пн           1  Мат Анализ        Иванов      Лекция
# 1           101   пн           2  Английский      Шептунов    Практика
# 2           101   пн           3          ОП       Рахимов      Лекция
# 3           101   вт           1     Алгебра    Заболотный      Лекция
# 4           101   вт           2  Мат Анализ        Иванов      Лекция
#
#                  Адрес
# 0  Васильевский остров
# 1  Васильевский остров
# 2  Васильевский остров
# 3             Петергоф
# 4             Петергоф

# %%
df = pd.read_csv('data.csv', sep='~', encoding = 'utf-8')
df.head()
# Out:
#                                     Oid       Id  Index  \
# 0  F2E2073C-2AA5-41EB-9129-0004321C1268  1033576    1.0
# 1  F2E2073C-2AA5-41EB-9129-0004321C1268  1033576    0.0
# 2  13051ECA-D481-45BD-A173-0005C340AE62  1047155    0.0
# 3  13051ECA-D481-45BD-A173-0005C340AE62  1047155    2.0
# 4  13051ECA-D481-45BD-A173-0005C340AE62  1047155    3.0
#
#                      Start                      End  \
# 0  2018-09-29 10:50:00.000  2018-09-29 12:30:00.000
# 1  2018-09-22 10:50:00.000  2018-09-22 12:30:00.000
# 2  2018-09-05 10:30:00.000  2018-09-05 12:00:00.000
# 3  2018-09-19 10:30:00.000  2018-09-19 12:00:00.000
# 4  2018-09-26 10:30:00.000  2018-09-26 12:00:00.000
#
#                          ContingentUnit                    EducatorAssignment  \
# 0  2653BA9C-C524-46CD-BCE7-CCE24CA92DB9  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 1  2653BA9C-C524-46CD-BCE7-CCE24CA92DB9  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 2  8C7F8906-0816-4300-9EDF-8283B99AE88E  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 3  8C7F8906-0816-4300-9EDF-8283B99AE88E  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 4  8C7F8906-0816-4300-9EDF-8283B99AE88E  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
#
#   EducatorsDisplayText EducatorsDisplayTextEnglish  \
# 0       сол и.е,рапудф              .l seaof,pdriu
# 1       сол и.е,рапудф              .l seaof,pdriu
# 2      ые. аовнд,црязт           riv.spe ,coaynztf
# 3      ые. аовнд,црязт           riv.spe ,coaynztf
# 4      ые. аовнд,црязт           riv.spe ,coaynztf
#
#                                 LocationsDisplayText  \
# 0  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 1  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 2                          В.О., 6 линия, д. 15, 212
# 3                          В.О., 6 линия, д. 15, 212
# 4                          В.О., 6 линия, д. 15, 212
#
#                          LocationsDisplayTextEnglish  \
# 0  V.O., Universitetskaya nab. 7-9-11, letter A, ...
# 1  V.O., Universitetskaya nab. 7-9-11, letter A, ...
# 2                             V.O., 6 liniya 15, 212
# 3                             V.O., 6 liniya 15, 212
# 4                             V.O., 6 liniya 15, 212
#
#                                        Subject  \
# 0           Алгоритмы в биоинформатике, лекция
# 1           Алгоритмы в биоинформатике, лекция
# 2  Мультимедийные технологии в дизайне, лекция
# 3  Мультимедийные технологии в дизайне, лекция
# 4  Мультимедийные технологии в дизайне, лекция
#
#                                SubjectEnglish  \
# 0          Bioinformatics Algorithms, lecture
# 1          Bioinformatics Algorithms, lecture
# 2  Multimedia Technologies in Design, lecture
# 3  Multimedia Technologies in Design, lecture
# 4  Multimedia Technologies in Design, lecture
#
#                StudyEventsTimeTableKind  Properties  WebAvailability  Cohort
# 0  02030202-AC4F-4908-971C-C83ACCBE358C           0                1       0
# 1  02030202-AC4F-4908-971C-C83ACCBE358C           0                1       0
# 2  02030202-AC4F-4908-971C-C83ACCBE358C           0                1       0
# 3  02030202-AC4F-4908-971C-C83ACCBE358C           0                1       0
# 4  02030202-AC4F-4908-971C-C83ACCBE358C           0                1       0

# %%
df = pd.read_csv('data.csv', sep='~', encoding = 'utf-8', usecols=['Id', 'Start', 'End', 'EducatorAssignment', 'LocationsDisplayText', 'Subject'])
df.head()
# Out:
#         Id                    Start                      End  \
# 0  1033576  2018-09-29 10:50:00.000  2018-09-29 12:30:00.000
# 1  1033576  2018-09-22 10:50:00.000  2018-09-22 12:30:00.000
# 2  1047155  2018-09-05 10:30:00.000  2018-09-05 12:00:00.000
# 3  1047155  2018-09-19 10:30:00.000  2018-09-19 12:00:00.000
# 4  1047155  2018-09-26 10:30:00.000  2018-09-26 12:00:00.000
#
#                      EducatorAssignment  \
# 0  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 1  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 2  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 3  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 4  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
#
#                                 LocationsDisplayText  \
# 0  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 1  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 2                          В.О., 6 линия, д. 15, 212
# 3                          В.О., 6 линия, д. 15, 212
# 4                          В.О., 6 линия, д. 15, 212
#
#                                        Subject
# 0           Алгоритмы в биоинформатике, лекция
# 1           Алгоритмы в биоинформатике, лекция
# 2  Мультимедийные технологии в дизайне, лекция
# 3  Мультимедийные технологии в дизайне, лекция
# 4  Мультимедийные технологии в дизайне, лекция

# %%
df.columns = ['Номер группы', 'Start', 'End', 'Преподаватель', 'Адрес', 'Предмет']
df.head()
# Out:
#    Номер группы                    Start                      End  \
# 0       1033576  2018-09-29 10:50:00.000  2018-09-29 12:30:00.000
# 1       1033576  2018-09-22 10:50:00.000  2018-09-22 12:30:00.000
# 2       1047155  2018-09-05 10:30:00.000  2018-09-05 12:00:00.000
# 3       1047155  2018-09-19 10:30:00.000  2018-09-19 12:00:00.000
# 4       1047155  2018-09-26 10:30:00.000  2018-09-26 12:00:00.000
#
#                           Преподаватель  \
# 0  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 1  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 2  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 3  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 4  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
#
#                                                Адрес  \
# 0  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 1  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 2                          В.О., 6 линия, д. 15, 212
# 3                          В.О., 6 линия, д. 15, 212
# 4                          В.О., 6 линия, д. 15, 212
#
#                                        Предмет
# 0           Алгоритмы в биоинформатике, лекция
# 1           Алгоритмы в биоинформатике, лекция
# 2  Мультимедийные технологии в дизайне, лекция
# 3  Мультимедийные технологии в дизайне, лекция
# 4  Мультимедийные технологии в дизайне, лекция

# %%
df['Предмет'].apply(str);

# %%
df['Вид занятия']=df['Предмет'].str.split(',').str.get(1)
df['Предмет']=df['Предмет'].str.split(',').str.get(0)

# %%
df.head()
# Out:
#    Номер группы                    Start                      End  \
# 0       1033576  2018-09-29 10:50:00.000  2018-09-29 12:30:00.000
# 1       1033576  2018-09-22 10:50:00.000  2018-09-22 12:30:00.000
# 2       1047155  2018-09-05 10:30:00.000  2018-09-05 12:00:00.000
# 3       1047155  2018-09-19 10:30:00.000  2018-09-19 12:00:00.000
# 4       1047155  2018-09-26 10:30:00.000  2018-09-26 12:00:00.000
#
#                           Преподаватель  \
# 0  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 1  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 2  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 3  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 4  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
#
#                                                Адрес  \
# 0  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 1  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 2                          В.О., 6 линия, д. 15, 212
# 3                          В.О., 6 линия, д. 15, 212
# 4                          В.О., 6 линия, д. 15, 212
#
#                                Предмет Вид занятия
# 0           Алгоритмы в биоинформатике      лекция
# 1           Алгоритмы в биоинформатике      лекция
# 2  Мультимедийные технологии в дизайне      лекция
# 3  Мультимедийные технологии в дизайне      лекция
# 4  Мультимедийные технологии в дизайне      лекция

# %%
df['День'] = df['Start'].str.split(' ').str.get(0)
df['Время начала'] = df['Start'].str.split(' ').str.get(1)
df['Время окончания'] = df['End'].str.split(' ').str.get(1)

# %%
df = df[['Номер группы', 'Преподаватель', 'Адрес', 'Предмет', 'Вид занятия', 'День', 'Время начала', 'Время окончания']]
df.head()
# Out:
#    Номер группы                         Преподаватель  \
# 0       1033576  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 1       1033576  724FF90E-ECFD-479F-91B0-5D6B60776DB8
# 2       1047155  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 3       1047155  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
# 4       1047155  7CA0F2E2-BB52-4AC2-BB60-6ABB2D8DD49E
#
#                                                Адрес  \
# 0  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 1  В.О., Университетская наб., д. 7-9-11, лит. А,...
# 2                          В.О., 6 линия, д. 15, 212
# 3                          В.О., 6 линия, д. 15, 212
# 4                          В.О., 6 линия, д. 15, 212
#
#                                Предмет Вид занятия        День  Время начала  \
# 0           Алгоритмы в биоинформатике      лекция  2018-09-29  10:50:00.000
# 1           Алгоритмы в биоинформатике      лекция  2018-09-22  10:50:00.000
# 2  Мультимедийные технологии в дизайне      лекция  2018-09-05  10:30:00.000
# 3  Мультимедийные технологии в дизайне      лекция  2018-09-19  10:30:00.000
# 4  Мультимедийные технологии в дизайне      лекция  2018-09-26  10:30:00.000
#
#   Время окончания
# 0    12:30:00.000
# 1    12:30:00.000
# 2    12:00:00.000
# 3    12:00:00.000
# 4    12:00:00.000
